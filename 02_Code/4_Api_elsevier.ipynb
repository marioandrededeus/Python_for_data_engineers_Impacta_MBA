# %% [markdown]
# # API - IEEE

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import os
import glob
import sqlite3
import yaml
import json
import requests
from datetime import datetime

import warnings
warnings.simplefilter(action = 'ignore', category = FutureWarning)

from functions import read_bib
from functions import load_bib
from functions import write_yaml
from functions import write_json
from functions import write_csv
from functions import read_yaml

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 1000)

# %% [markdown]
# # Params

# %%
#API_Params
config_api = read_yaml("../05_Config/config_api.yaml")
print("config_api: \n", config_api)

#API Elsevier
config_query = read_yaml("../05_Config/config_query.yaml")
print("config_query: \n", config_query)

url = f"https://api.elsevier.com/content/search/sciencedirect?query={config_query['api_elsevier_string_search']}&apiKey={config_api['apikey_elsevier']}"
print(url)
# Out:
# ../05_Config/config_api.yaml read successfully
#
# config_api:
#  {'apikey_ieee': '3jk2p7za5jtd7a39gwknygvk', 'format': 'json', 'sort_order': 'asc', 'sort_field': 'article', 'apikey_elsevier': '7f59af901d2d86f78a1fd60c1bf9426a'}
#
#
# ../05_Config/config_query.yaml read successfully
#
# config_query:
#  {'call_api_ieee': False, 'call_api_eslsevier': False, 'max_api_ieee_pagination': 2, 'api_ieee_field_search': 'article_title', 'api_ieee_string_search': 'big+data', 'api_elsevier_string_search': 'big+data', 'path_db': '../03_OutputFiles/doi.db', 'use_query_sql_bib_csv': True, 'use_query_sql_ieee': True, 'query_bib_csv': "SELECT * FROM bib_csv WHERE abstract LIKE '%big data%' OR abstract LIKE '%quality%'", 'query_ieee': "SELECT * FROM api_ieee WHERE  abstract LIKE '%big data%' OR abstract LIKE '%quality%'", 'output_extensions': ['json', 'csv', 'yaml']}
# https://api.elsevier.com/content/search/sciencedirect?query=big+data&apiKey=7f59af901d2d86f78a1fd60c1bf9426a

# %%
req_elsevier = requests.get(url)

if req_elsevier.status_code >= 400:
    print('Status code: ',req_elsevier.status_code, '\nProvavelmente foi atingido o limite de consultas diario!')
else:
    dict_api_elsevier = req_elsevier.json()

dict_api_elsevier = req_elsevier.json()

for i, j in enumerate (dict_api_elsevier['search-results']['entry']):
    print(i,j,'\n\n')
# Out:
# 0 {'@_fa': 'true', 'load-date': '2022-11-11T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S2214579622000521'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S2214579622000521?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.bdr.2022.100358', 'prism:url': 'https://api.elsevier.com/content/article/pii/S2214579622000521', 'dc:title': 'Data-Efficient Performance Modeling for Configurable Big Data Frameworks by Reducing Information Overlap Between Training Examples', 'dc:creator': 'Zhiqiang Liu', 'prism:publicationName': 'Big Data Research', 'prism:volume': '30', 'prism:coverDate': '2022-11-28', 'prism:startingPage': '100358', 'prism:doi': '10.1016/j.bdr.2022.100358', 'openaccess': False, 'pii': 'S2214579622000521', 'authors': {'author': [{'$': 'Zhiqiang Liu'}, {'$': 'Xuanhua Shi'}, {'$': 'Hai Jin'}]}}
#
#
# 1 {'@_fa': 'true', 'load-date': '2022-11-17T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0040162522006758'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0040162522006758?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.techfore.2022.122154', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0040162522006758', 'dc:title': 'Examining the role of virtue ethics and big data in enhancing viable, sustainable, and digital supply chain performance', 'dc:creator': 'Surajit Bag', 'prism:publicationName': 'Technological Forecasting and Social Change', 'prism:volume': '186', 'prism:coverDate': '2023-01-31', 'prism:startingPage': '122154', 'prism:doi': '10.1016/j.techfore.2022.122154', 'openaccess': False, 'pii': 'S0040162522006758', 'authors': {'author': [{'$': 'Surajit Bag'}, {'$': 'Muhammad Sabbir Rahman'}, {'$': 'Pratibha Ram'}]}}
#
#
# 2 {'@_fa': 'true', 'load-date': '2020-08-03T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S1935861X20302163'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S1935861X20302163?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.brs.2020.07.018', 'prism:url': 'https://api.elsevier.com/content/article/pii/S1935861X20302163', 'dc:title': 'Large-scale analysis of interindividual variability in theta-burst stimulation data: Results from the ‘Big TMS Data Collaboration’', 'dc:creator': 'Daniel T. Corp', 'prism:publicationName': 'Brain Stimulation', 'prism:volume': '13', 'prism:coverDate': '2020-10-31', 'prism:startingPage': '1476', 'prism:endingPage': '1488', 'prism:doi': '10.1016/j.brs.2020.07.018', 'openaccess': True, 'pii': 'S1935861X20302163', 'authors': {'author': [{'$': 'Daniel T. Corp'}, {'$': 'Hannah G. K. Bereznicki'}, {'$': 'Peter G. Enticott'}]}}
#
#
# 3 {'@_fa': 'true', 'load-date': '2022-09-29T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0306261922012430'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0306261922012430?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.apenergy.2022.119986', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0306261922012430', 'dc:title': 'Digital twin and big data-driven sustainable smart manufacturing based on information management systems for energy-intensive industries', 'dc:creator': 'Shuaiyin Ma', 'prism:publicationName': 'Applied Energy', 'prism:volume': '326', 'prism:coverDate': '2022-11-15', 'prism:startingPage': '119986', 'prism:doi': '10.1016/j.apenergy.2022.119986', 'openaccess': True, 'pii': 'S0306261922012430', 'authors': {'author': [{'$': 'Shuaiyin Ma'}, {'$': 'Wei Ding'}, {'$': 'Haidong Yang'}]}}
#
#
# 4 {'@_fa': 'true', 'load-date': '2022-07-08T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S2095927322002997'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S2095927322002997?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.scib.2022.07.015', 'prism:url': 'https://api.elsevier.com/content/article/pii/S2095927322002997', 'dc:title': 'Measuring and evaluating SDG indicators with Big Earth Data', 'dc:creator': 'Huadong Guo', 'prism:publicationName': 'Science Bulletin', 'prism:volume': '67', 'prism:coverDate': '2022-09-15', 'prism:startingPage': '1792', 'prism:endingPage': '1801', 'prism:doi': '10.1016/j.scib.2022.07.015', 'openaccess': True, 'pii': 'S2095927322002997', 'authors': {'author': [{'$': 'Huadong Guo'}, {'$': 'Dong Liang'}, {'$': 'Zeeshan Shirazi'}]}}
#
#
# 5 {'@_fa': 'true', 'load-date': '2022-11-23T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S240584402203122X'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S240584402203122X?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.heliyon.2022.e11834', 'prism:url': 'https://api.elsevier.com/content/article/pii/S240584402203122X', 'dc:title': 'Connotation, characteristics and framework of coal mine safety big data', 'dc:creator': 'Wanguan Qiao', 'prism:publicationName': 'Heliyon', 'prism:volume': '8', 'prism:coverDate': '2022-11-30', 'prism:startingPage': 'e11834', 'prism:doi': '10.1016/j.heliyon.2022.e11834', 'openaccess': True, 'pii': 'S240584402203122X', 'authors': {'author': [{'$': 'Wanguan Qiao'}, {'$': 'Xue Chen'}]}}
#
#
# 6 {'@_fa': 'true', 'load-date': '2022-06-25T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S2667091722000152'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S2667091722000152?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.urbmob.2022.100027', 'prism:url': 'https://api.elsevier.com/content/article/pii/S2667091722000152', 'dc:title': 'Simulating micro-level attributes of railway passengers using big data', 'dc:creator': 'Eusebio Odiari', 'prism:publicationName': 'Journal of Urban Mobility', 'prism:volume': '2', 'prism:coverDate': '2022-12-31', 'prism:startingPage': '100027', 'prism:doi': '10.1016/j.urbmob.2022.100027', 'openaccess': True, 'pii': 'S2667091722000152', 'authors': {'author': [{'$': 'Eusebio Odiari'}, {'$': 'Mark Birkin'}]}}
#
#
# 7 {'@_fa': 'true', 'load-date': '2022-09-23T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0959652622038331'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0959652622038331?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.jclepro.2022.134261', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0959652622038331', 'dc:title': 'Digital and intelligent empowerment: Can big data capability drive green process innovation of manufacturing enterprises?', 'dc:creator': 'Hongna Tian', 'prism:publicationName': 'Journal of Cleaner Production', 'prism:volume': '377', 'prism:coverDate': '2022-12-01', 'prism:startingPage': '134261', 'prism:doi': '10.1016/j.jclepro.2022.134261', 'openaccess': False, 'pii': 'S0959652622038331', 'authors': {'author': [{'$': 'Hongna Tian'}, {'$': 'Yunfang Li'}, {'$': 'Yan Zhang'}]}}
#
#
# 8 {'@_fa': 'true', 'load-date': '2022-08-27T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S2405844022016000'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S2405844022016000?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.heliyon.2022.e10312', 'prism:url': 'https://api.elsevier.com/content/article/pii/S2405844022016000', 'dc:title': 'Impact of big data resources on clinicians’ activation of prior medical knowledge', 'dc:creator': 'Sufen Wang', 'prism:publicationName': 'Heliyon', 'prism:volume': '8', 'prism:coverDate': '2022-09-30', 'prism:startingPage': 'e10312', 'prism:doi': '10.1016/j.heliyon.2022.e10312', 'openaccess': True, 'pii': 'S2405844022016000', 'authors': {'author': [{'$': 'Sufen Wang'}, {'$': 'Junyi Yuan'}, {'$': 'Changqing Pan'}]}}
#
#
# 9 {'@_fa': 'true', 'load-date': '2022-09-09T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0160791X2200255X'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0160791X2200255X?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.techsoc.2022.102114', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0160791X2200255X', 'dc:title': 'A csQCA study of value creation in logistics collaboration by big data: A perspective from companies in China', 'dc:creator': 'Qiaohong Pan', 'prism:publicationName': 'Technology in Society', 'prism:volume': '71', 'prism:coverDate': '2022-11-30', 'prism:startingPage': '102114', 'prism:doi': '10.1016/j.techsoc.2022.102114', 'openaccess': False, 'pii': 'S0160791X2200255X', 'authors': {'author': [{'$': 'Qiaohong Pan'}, {'$': 'Wenping Luo'}, {'$': 'Yi Fu'}]}}
#
#
# 10 {'@_fa': 'true', 'load-date': '2022-09-18T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0965997822001491'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0965997822001491?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.advengsoft.2022.103246', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0965997822001491', 'dc:title': 'A critical evaluation of handling uncertainty in Big Data processing', 'dc:creator': 'Ekansh Upadhyay', 'prism:publicationName': 'Advances in Engineering Software', 'prism:volume': '173', 'prism:coverDate': '2022-11-30', 'prism:startingPage': '103246', 'prism:doi': '10.1016/j.advengsoft.2022.103246', 'openaccess': False, 'pii': 'S0965997822001491', 'authors': {'author': 'Ekansh Upadhyay'}}
#
#
# 11 {'@_fa': 'true', 'load-date': '2022-09-13T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S1467089522000276'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S1467089522000276?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.accinf.2022.100575', 'prism:url': 'https://api.elsevier.com/content/article/pii/S1467089522000276', 'dc:title': 'V-Matrix: A wave theory of value creation for big data', 'dc:creator': 'Guido L. Geerts', 'prism:publicationName': 'International Journal of Accounting Information Systems', 'prism:volume': '47', 'prism:coverDate': '2022-12-31', 'prism:startingPage': '100575', 'prism:doi': '10.1016/j.accinf.2022.100575', 'openaccess': False, 'pii': 'S1467089522000276', 'authors': {'author': [{'$': 'Guido L. Geerts'}, {'$': "Daniel E. O'Leary"}]}}
#
#
# 12 {'@_fa': 'true', 'load-date': '2022-02-04T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0306457322000176'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0306457322000176?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.ipm.2022.102888', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0306457322000176', 'dc:title': 'Application of cognitive computing in healthcare, cybersecurity, big data and IoT: A literature review', 'dc:creator': 'A. G. Sreedevi', 'prism:publicationName': 'Information Processing & Management', 'prism:volume': '59', 'prism:coverDate': '2022-03-31', 'prism:startingPage': '102888', 'prism:doi': '10.1016/j.ipm.2022.102888', 'openaccess': False, 'pii': 'S0306457322000176', 'authors': {'author': [{'$': 'A. G. Sreedevi'}, {'$': 'T. Nitya Harshitha'}, {'$': 'P. Shankar'}]}}
#
#
# 13 {'@_fa': 'true', 'load-date': '2022-11-29T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/B9780128212042000738'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/B9780128212042000738?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/B978-0-12-821204-2.00073-8', 'prism:url': 'https://api.elsevier.com/content/article/pii/B9780128212042000738', 'dc:title': 'Big Data applications in power systems', 'dc:creator': 'Xavier Dominguez', 'prism:publicationName': 'Encyclopedia of Electrical and Electronic Power Engineering', 'prism:coverDate': '2023-12-31', 'prism:startingPage': '497', 'prism:endingPage': '506', 'prism:doi': '10.1016/B978-0-12-821204-2.00073-8', 'openaccess': False, 'pii': 'B9780128212042000738', 'authors': {'author': [{'$': 'Xavier Dominguez'}, {'$': 'Alvaro Prado'}, {'$': 'Pablo Arboleya'}]}}
#
#
# 14 {'@_fa': 'true', 'load-date': '2022-05-25T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0925231222006415'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0925231222006415?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.neucom.2021.06.101', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0925231222006415', 'dc:title': 'A new big data triclustering approach for extracting three-dimensional patterns in precision agriculture', 'dc:creator': 'Laura Melgar-García', 'prism:publicationName': 'Neurocomputing', 'prism:volume': '500', 'prism:coverDate': '2022-08-21', 'prism:startingPage': '268', 'prism:endingPage': '278', 'prism:doi': '10.1016/j.neucom.2021.06.101', 'openaccess': False, 'pii': 'S0925231222006415', 'authors': {'author': [{'$': 'Laura Melgar-García'}, {'$': 'David Gutiérrez-Avilés'}, {'$': 'Cristina Rubio-Escudero'}]}}
#
#
# 15 {'@_fa': 'true', 'load-date': '2022-09-12T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S2212041622000742'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S2212041622000742?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.ecoser.2022.101478', 'prism:url': 'https://api.elsevier.com/content/article/pii/S2212041622000742', 'dc:title': 'A review of machine learning and big data applications in addressing ecosystem service research gaps', 'dc:creator': 'Kyle Manley', 'prism:publicationName': 'Ecosystem Services', 'prism:volume': '57', 'prism:coverDate': '2022-10-31', 'prism:startingPage': '101478', 'prism:doi': '10.1016/j.ecoser.2022.101478', 'openaccess': True, 'pii': 'S2212041622000742', 'authors': {'author': [{'$': 'Kyle Manley'}, {'$': 'Charity Nyelele'}, {'$': 'Benis N. Egoh'}]}}
#
#
# 16 {'@_fa': 'true', 'load-date': '2022-11-18T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0969698922002867'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0969698922002867?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.jretconser.2022.103193', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0969698922002867', 'dc:title': 'The intermediating role of big data analytics capability between responsive and proactive market orientations and firm performance in the retail industry', 'dc:creator': 'Fumikazu Morimura', 'prism:publicationName': 'Journal of Retailing and Consumer Services', 'prism:volume': '71', 'prism:coverDate': '2023-03-31', 'prism:startingPage': '103193', 'prism:doi': '10.1016/j.jretconser.2022.103193', 'openaccess': False, 'pii': 'S0969698922002867', 'authors': {'author': [{'$': 'Fumikazu Morimura'}, {'$': 'Yuji Sakagawa'}]}}
#
#
# 17 {'@_fa': 'true', 'load-date': '2022-10-18T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S2665917422001684'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S2665917422001684?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.measen.2022.100534', 'prism:url': 'https://api.elsevier.com/content/article/pii/S2665917422001684', 'dc:title': 'AI-based big data analytics model for medical applications', 'dc:creator': 'S. Lokesh', 'prism:publicationName': 'Measurement: Sensors', 'prism:volume': '24', 'prism:coverDate': '2022-12-31', 'prism:startingPage': '100534', 'prism:doi': '10.1016/j.measen.2022.100534', 'openaccess': True, 'pii': 'S2665917422001684', 'authors': {'author': [{'$': 'S. Lokesh'}, {'$': 'Sudeshna Chakraborty'}, {'$': 'R. Muruganantham'}]}}
#
#
# 18 {'@_fa': 'true', 'load-date': '2022-09-23T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S2213138822007238'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S2213138822007238?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.seta.2022.102674', 'prism:url': 'https://api.elsevier.com/content/article/pii/S2213138822007238', 'dc:title': 'The relationship between soil microbial diversity and angelica planting based on network big data', 'dc:creator': 'Yinan Peng', 'prism:publicationName': 'Sustainable Energy Technologies and Assessments', 'prism:volume': '53', 'prism:coverDate': '2022-10-31', 'prism:startingPage': '102674', 'prism:doi': '10.1016/j.seta.2022.102674', 'openaccess': False, 'pii': 'S2213138822007238', 'authors': {'author': [{'$': 'Yinan Peng'}, {'$': 'Ze Ye'}, {'$': 'Zhiye Wang'}]}}
#
#
# 19 {'@_fa': 'true', 'load-date': '2022-10-07T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0007681322001252'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0007681322001252?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.bushor.2022.10.001', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0007681322001252', 'dc:title': 'Big web data: Challenges related to data, technology, legality, and ethics', 'dc:creator': 'Vlad Krotov', 'prism:publicationName': 'Business Horizons', 'prism:coverDate': '2022-10-07', 'prism:doi': '10.1016/j.bushor.2022.10.001', 'openaccess': False, 'pii': 'S0007681322001252', 'authors': {'author': [{'$': 'Vlad Krotov'}, {'$': 'Leigh Johnson'}]}}
#
#
# 20 {'@_fa': 'true', 'load-date': '2022-04-25T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0167739X22001492'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0167739X22001492?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.future.2022.04.020', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0167739X22001492', 'dc:title': 'Big data architecture for connected vehicles: Feedback and application examples from an automotive group', 'dc:creator': 'Ahmed Mostefaoui', 'prism:publicationName': 'Future Generation Computer Systems', 'prism:volume': '134', 'prism:coverDate': '2022-09-30', 'prism:startingPage': '374', 'prism:endingPage': '387', 'prism:doi': '10.1016/j.future.2022.04.020', 'openaccess': False, 'pii': 'S0167739X22001492', 'authors': {'author': [{'$': 'Ahmed Mostefaoui'}, {'$': 'Mohammed Amine Merzoug'}, {'$': 'François Dessables'}]}}
#
#
# 21 {'@_fa': 'true', 'load-date': '2022-11-01T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S2210537922001512'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S2210537922001512?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.suscom.2022.100820', 'prism:url': 'https://api.elsevier.com/content/article/pii/S2210537922001512', 'dc:title': 'The product marketing model of the economic zone by the sensor big data mining algorithm', 'dc:creator': 'Yishu Liu', 'prism:publicationName': 'Sustainable Computing: Informatics and Systems', 'prism:volume': '36', 'prism:coverDate': '2022-12-31', 'prism:startingPage': '100820', 'prism:doi': '10.1016/j.suscom.2022.100820', 'openaccess': False, 'pii': 'S2210537922001512', 'authors': {'author': [{'$': 'Yishu Liu'}, {'$': 'Jingya Cao'}, {'$': 'Qi Zhang'}]}}
#
#
# 22 {'@_fa': 'true', 'load-date': '2022-11-05T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S266710262200078X'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S266710262200078X?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.imed.2022.10.003', 'prism:url': 'https://api.elsevier.com/content/article/pii/S266710262200078X', 'dc:title': 'Practice of big data and artificial intelligence in epidemic surveillance and containment', 'dc:creator': 'Zengtao Jiao', 'prism:publicationName': 'Intelligent Medicine', 'prism:coverDate': '2022-11-05', 'prism:doi': '10.1016/j.imed.2022.10.003', 'openaccess': True, 'pii': 'S266710262200078X', 'authors': {'author': [{'$': 'Zengtao Jiao'}, {'$': 'Hanran Ji'}, {'$': 'Xiaopeng Qi'}]}}
#
#
# 23 {'@_fa': 'true', 'load-date': '2022-07-23T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0267364922000723'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0267364922000723?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.clsr.2022.105729', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0267364922000723', 'dc:title': 'Regulating the use of big data: Justifications, perspectives and the Chinese way forward', 'dc:creator': 'Wenjie Ding', 'prism:publicationName': 'Computer Law & Security Review', 'prism:volume': '46', 'prism:coverDate': '2022-09-30', 'prism:startingPage': '105729', 'prism:doi': '10.1016/j.clsr.2022.105729', 'openaccess': False, 'pii': 'S0267364922000723', 'authors': {'author': [{'$': 'Wenjie Ding'}, {'$': 'Li Chen'}]}}
#
#
# 24 {'@_fa': 'true', 'load-date': '2022-08-07T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0923474822000273'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0923474822000273?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.jengtecman.2022.101697', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0923474822000273', 'dc:title': 'The role of big data analytics and decision-making in achieving project success', 'dc:creator': 'Riaz Ahmed', 'prism:publicationName': 'Journal of Engineering and Technology Management', 'prism:volume': '65', 'prism:coverDate': '2022-09-30', 'prism:startingPage': '101697', 'prism:doi': '10.1016/j.jengtecman.2022.101697', 'openaccess': False, 'pii': 'S0923474822000273', 'authors': {'author': [{'$': 'Riaz Ahmed'}, {'$': 'Sumayya Shaheen'}, {'$': 'Simon P. Philbin'}]}}

# %%
#Parsing json to df
doi = [i['prism:doi'] for i in dict_api_elsevier['search-results']['entry']]
title = [i['dc:title'] for i in dict_api_elsevier['search-results']['entry']]
publisher = [i['prism:publicationName'] for i in dict_api_elsevier['search-results']['entry']]
publication_year = [i['prism:coverDate'][:4] for i in dict_api_elsevier['search-results']['entry']]

#Adjusting Authors feature
authors = [i.get('authors') for i in dict_api_elsevier['search-results']['entry']]
list_index = []
list_authors = []
for i, x in enumerate(authors):
    if type(x.get('author')) == str:
        list_index.append(i)
        list_authors.append(x.get('author'))
    
    else:
        for y in x.get('author'):
            list_index.append(i)
            list_authors.append(y.get('$'))
df_author = pd.DataFrame({'index':list_index, 'authors': list_authors})
df_author = df_author.groupby('index')['authors'].apply(list)
authors = df_author.tolist()

#Creating DataFrame
df_api_elsevier = pd.DataFrame({'doi': doi,
                                'title': title,
                                'publisher': publisher,
                                'publication_year': publication_year,
                                'authors': authors})

#Convert list to string
df_api_elsevier['authors'] = df_api_elsevier['authors'].map(lambda x: ', '.join(x))

#Insert id_search [elsevier_YYYYMMDD_HH_MM_SS]
search_id = datetime.now().strftime("elsevier_%Y%m%d_%H_%M_%S")
df_api_elsevier.insert(0, 'search_id', search_id)
print(df_api_elsevier.dtypes)
df_api_elsevier.head()
# Out:
# search_id           object
# doi                 object
# title               object
# publisher           object
# publication_year    object
# authors             object
# dtype: object
#                     search_id                             doi                                              title                                    publisher publication_year                                            authors
# 0  elsevier_20221204_19_43_57       10.1016/j.bdr.2022.100358  Data-Efficient Performance Modeling for Config...                            Big Data Research             2022                 Zhiqiang Liu, Xuanhua Shi, Hai Jin
# 1  elsevier_20221204_19_43_57  10.1016/j.techfore.2022.122154  Examining the role of virtue ethics and big da...  Technological Forecasting and Social Change             2023  Surajit Bag, Muhammad Sabbir Rahman, Pratibha Ram
# 2  elsevier_20221204_19_43_57       10.1016/j.brs.2020.07.018  Large-scale analysis of interindividual variab...                            Brain Stimulation             2020  Daniel T. Corp, Hannah G. K. Bereznicki, Peter...
# 3  elsevier_20221204_19_43_57  10.1016/j.apenergy.2022.119986  Digital twin and big data-driven sustainable s...                               Applied Energy             2022                Shuaiyin Ma, Wei Ding, Haidong Yang
# 4  elsevier_20221204_19_43_57      10.1016/j.scib.2022.07.015  Measuring and evaluating SDG indicators with B...                             Science Bulletin             2022           Huadong Guo, Dong Liang, Zeeshan Shirazi

# %% [markdown]
# # Export to Database

# %%
#Exporting to SQlite database
dbfile = config_query['path_db']
tabela ='api_elsevier'
db = sqlite3.connect(dbfile)
sqlDataTypes={}
for c in df_api_elsevier.columns:
    if df_api_elsevier[c].dtype.kind == 'i':  
        sqlDataTypes[c]='INTEGER'
    elif df_api_elsevier[c].dtype.kind == 'f':
        sqlDataTypes[c]='REAL'
    else:
        sqlDataTypes[c]='TEXT'
df_api_elsevier.to_sql(tabela, index=False, if_exists='append', dtype = sqlDataTypes, con = db)   
db.commit()
db.close()

# %%
#Check db content

db = sqlite3.connect(dbfile)

tabela = 'api_elsevier'

query_api = pd.read_sql_query(f'select * from {tabela} LIMIT 10', db)
display(pd.read_sql_query(f'select count(*) from {tabela}', db))
display(query_api)
# Out:
#    count(*)
# 0        50
#                     search_id                             doi                                              title                                    publisher publication_year                                            authors
# 0  elsevier_20221204_19_43_57       10.1016/j.bdr.2022.100358  Data-Efficient Performance Modeling for Config...                            Big Data Research             2022                 Zhiqiang Liu, Xuanhua Shi, Hai Jin
# 1  elsevier_20221204_19_43_57  10.1016/j.techfore.2022.122154  Examining the role of virtue ethics and big da...  Technological Forecasting and Social Change             2023  Surajit Bag, Muhammad Sabbir Rahman, Pratibha Ram
# 2  elsevier_20221204_19_43_57       10.1016/j.brs.2020.07.018  Large-scale analysis of interindividual variab...                            Brain Stimulation             2020  Daniel T. Corp, Hannah G. K. Bereznicki, Peter...
# 3  elsevier_20221204_19_43_57  10.1016/j.apenergy.2022.119986  Digital twin and big data-driven sustainable s...                               Applied Energy             2022                Shuaiyin Ma, Wei Ding, Haidong Yang
# 4  elsevier_20221204_19_43_57      10.1016/j.scib.2022.07.015  Measuring and evaluating SDG indicators with B...                             Science Bulletin             2022           Huadong Guo, Dong Liang, Zeeshan Shirazi
# 5  elsevier_20221204_19_43_57   10.1016/j.heliyon.2022.e11834  Connotation, characteristics and framework of ...                                      Heliyon             2022                             Wanguan Qiao, Xue Chen
# 6  elsevier_20221204_19_43_57    10.1016/j.urbmob.2022.100027  Simulating micro-level attributes of railway p...                    Journal of Urban Mobility             2022                        Eusebio Odiari, Mark Birkin
# 7  elsevier_20221204_19_43_57   10.1016/j.jclepro.2022.134261  Digital and intelligent empowerment: Can big d...                Journal of Cleaner Production             2022                 Hongna Tian, Yunfang Li, Yan Zhang
# 8  elsevier_20221204_19_43_57   10.1016/j.heliyon.2022.e10312  Impact of big data resources on clinicians’ ac...                                      Heliyon             2022              Sufen Wang, Junyi Yuan, Changqing Pan
# 9  elsevier_20221204_19_43_57   10.1016/j.techsoc.2022.102114  A csQCA study of value creation in logistics c...                        Technology in Society             2022                   Qiaohong Pan, Wenping Luo, Yi Fu
