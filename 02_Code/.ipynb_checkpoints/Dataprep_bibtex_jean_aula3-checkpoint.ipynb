# %%
#!conda install -n impacta_env ipykernel --update-deps --force-reinstall
# !python3 -m pip install bibtexparser
# !python3 -m pip install pyyaml

# %%
import bibtexparser
import pandas as pd
import numpy as np
import os
import glob
import yaml

import warnings
warnings.simplefilter(action = 'ignore', category = FutureWarning)

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 300)

# %% [markdown]
# # Def Functions

# %%
#def1
def read_bib(file_path: str):
    '''
    Function to read and parse bib files to dataframe object.
    path: bib file path
    '''
    with open(file_path) as bibtex_file:
        bib_file = bibtexparser.load(bibtex_file)
    df = pd.DataFrame(bib_file.entries)
    
    return df
#########################################################################

#def2
def load_bib(folder_path: str):
    
    '''
    Function to: 
    1) read and parse bib files from a list of directories (folders); 
    2) concatenate multiple dataframes in an only one
    
    folder_path: directories path where are located the bib files
    
    '''
    
    #listing bib files path from acm directory
    list_files = []
    for file in glob.glob(f'{folder_path}/*.bib'):
        list_files.append(file)

    #loading each bib file listed
    list_df = []
    c = 1
    for file in list_files:
        df_temp = read_bib(file) #def
        list_df.append(df_temp)
        print(f'{c} de {len(list_files)}: {file}')
        c += 1

    #concatenating all files in a unique dataframe object
    df = pd.concat(list_df)
    print(f'Shape df_{folder}: ', df.shape)
    
    return df
#########################################################################

#def3
def write_yaml (data, file_name):
  with open(f'../03_OutputFiles/{file_name}.yaml', 'w') as output_file:
    yaml.dump_all(data.to_dict('records'), output_file, default_flow_style=False)
    print(f"{file_name}.yaml successfully written")
#########################################################################

#def4
def write_json (data, file_name):
  data.to_json(f'../03_OutputFiles/{file_name}.json', orient='records', indent=4)
  print(f"{file_name}.json successfully written")
#########################################################################

#def5
def write_csv (data, file_name):
  data.to_csv(f'../03_OutputFiles/{file_name}.csv',sep=';', index = False)
  print(f"{file_name}.csv successfully written")
#########################################################################

#def6
def read_yaml (file_name):
  with open(file_name, "r") as yamlfile:
      data = yaml.load(yamlfile, Loader=yaml.FullLoader)
      print(f"{file_name} read successfully")
  return data

def read_csv (file_name):
  csv_data = pd.read_csv(file_name, sep = ';')
  return csv_data

# %% [markdown]
# # Reading, loading and concatenating all bibtex files

# %%
list_folders = []
for folder in glob.glob(f'../01_Datasets/*'):
    list_folders.append(folder)
list_folders

list_df = []
for f in list_folders:
    print('\n',f)
    df_temp = load_bib(f) #def
    list_df.append(df_temp)
df_all_raw = pd.concat(list_df)
print('\nShape df_all_raw: ',df_all_raw.shape)
# Out:
#  ../01_Datasets/acm
# 1 de 15: ../01_Datasets/acm/acm (1).bib
# 2 de 15: ../01_Datasets/acm/acm (10).bib
# 3 de 15: ../01_Datasets/acm/acm (11).bib
# 4 de 15: ../01_Datasets/acm/acm (12).bib
# 5 de 15: ../01_Datasets/acm/acm (13).bib
# 6 de 15: ../01_Datasets/acm/acm (14).bib
# 7 de 15: ../01_Datasets/acm/acm (2).bib
# 8 de 15: ../01_Datasets/acm/acm (3).bib
# 9 de 15: ../01_Datasets/acm/acm (4).bib
# 10 de 15: ../01_Datasets/acm/acm (5).bib
# 11 de 15: ../01_Datasets/acm/acm (6).bib
# 12 de 15: ../01_Datasets/acm/acm (7).bib
# 13 de 15: ../01_Datasets/acm/acm (8).bib
# 14 de 15: ../01_Datasets/acm/acm (9).bib
# 15 de 15: ../01_Datasets/acm/acm.bib
# Shape df_../01_Datasets/sciencedirect:  (1451, 27)
#
#  ../01_Datasets/ieee
# 1 de 5: ../01_Datasets/ieee/ieee01.bib
# 2 de 5: ../01_Datasets/ieee/ieee02.bib
# 3 de 5: ../01_Datasets/ieee/ieee03.bib
# 4 de 5: ../01_Datasets/ieee/ieee04.bib
# 5 de 5: ../01_Datasets/ieee/ieee05.bib
# Shape df_../01_Datasets/sciencedirect:  (466, 18)
#
#  ../01_Datasets/sciencedirect
# 1 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664900981798.bib
# 2 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664900996606.bib
# 3 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901008566.bib
# 4 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901022672.bib
# 5 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901034634.bib
# 6 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901049390.bib
# 7 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901062597.bib
# 8 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901076219.bib
# 9 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901313104.bib
# 10 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901325707.bib
# 11 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901341946.bib
# 12 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901354705.bib
# 13 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901373091.bib
# 14 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901384565.bib
# 15 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901396061.bib
# 16 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901407156.bib
# 17 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901423447.bib
# 18 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901473402.bib
# 19 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901483538.bib
# 20 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901493338.bib
# 21 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901516463.bib
# 22 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901530660.bib
# 23 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901545863.bib
# 24 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901569366.bib
# 25 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901582313.bib
# 26 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901593466.bib
# 27 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901604197.bib
# 28 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901618620.bib
# 29 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901629453.bib
# 30 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901642131.bib
# 31 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901653154.bib
# 32 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901714428.bib
# 33 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901727203.bib
# 34 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901739254.bib
# 35 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901753759.bib
# 36 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901771138.bib
# 37 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901780783.bib
# 38 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901790793.bib
# 39 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901802926.bib
# 40 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901814134.bib
# 41 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901904068.bib
# 42 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901914229.bib
# 43 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901925196.bib
# 44 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901936569.bib
# 45 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901948081.bib
# 46 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901957848.bib
# 47 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901969577.bib
# 48 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901979356.bib
# 49 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664901990073.bib
# 50 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664902039403.bib
# 51 de 51: ../01_Datasets/sciencedirect/ScienceDirect_citations_1664902053739.bib
# Shape df_../01_Datasets/sciencedirect:  (4858, 22)
#
# Shape df_all_raw:  (6775, 27)

# %% [markdown]
# # Import JCS and Scimago CSV files

# %%
df_jcs = pd.read_csv(f'../jcr_scimago/jcs_2020.csv', sep = ';')
df_scimago = pd.read_csv(f'../jcr_scimago/scimagojr_2020.csv', sep = ';')

# df1.isna().sum()
df_scimago.head()
# Out:
# /tmp/ipykernel_2482/923300268.py:2: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_scimago = pd.read_csv(f'../jcr_scimago/scimagojr_2020.csv', sep = ';')
#    Rank     Sourceid                                  Title     Type                Issn     SJR SJR Best Quartile  H index  Total Docs. (2020)  Total Docs. (3years)  Total Refs.  Total Cites (3years)  Citable Docs. (3years) Cites / Doc. (2years) Ref. / Doc.         Country            Region  \
# 0     1        28773     Ca-A Cancer Journal for Clinicians  journal  15424863, 00079235  62,937                Q1      168                  47                   119         3452                 15499                      80                126,34       73,45   United States  Northern America
# 1     2        19434       MMWR Recommendations and Reports  journal  10575987, 15458601  40,949                Q1      143                  10                     9         1292                   492                       9                 50,00      129,20   United States  Northern America
# 2     3        20315  Nature Reviews Molecular Cell Biology  journal  14710072, 14710080  37,461                Q1      431                 115                   338         8439                 10844                     167                 32,83       73,38  United Kingdom    Western Europe
# 3     4        29431         Quarterly Journal of Economics  journal  00335533, 15314650  34,573                Q1      259                  40                   110         2733                  1945                     109                 16,00       68,33  United Kingdom    Western Europe
# 4     5  21100812243               Nature Reviews Materials  journal            20588437  32,011                Q1      108                  92                   264        10632                 11188                     138                 32,15      115,57  United Kingdom    Western Europe
#
#                                           Publisher   Coverage                                         Categories
# 0                                   Wiley-Blackwell  1950-2020                     Hematology (Q1); Oncology (Q1)
# 1  Centers for Disease Control and Prevention (CDC)  1990-2020  Epidemiology (Q1); Health Information Manageme...
# 2                           Nature Publishing Group  2000-2020          Cell Biology (Q1); Molecular Biology (Q1)
# 3                           Oxford University Press  1886-2020                    Economics and Econometrics (Q1)
# 4                           Nature Publishing Group  2016-2020  Biomaterials (Q1); Electronic, Optical and Mag...

# %%
df_jcs.head()
# Out:
#    Rank                     Full Journal Title Total Cites  Unnamed: 3 Journal Impact Factor  Eigenfactor Score  Unnamed: 6  Unnamed: 7
# 0     1     CA-A CANCER JOURNAL FOR CLINICIANS      55,868         NaN               508.702            0.10514         NaN         NaN
# 1     2  NATURE REVIEWS MOLECULAR CELL BIOLOGY      58,477         NaN                94.444            0.07548         NaN         NaN
# 2     3        NEW ENGLAND JOURNAL OF MEDICINE     464,351         NaN                91.245            0.63118         NaN         NaN
# 3     4          NATURE REVIEWS DRUG DISCOVERY      41,989         NaN                84.694            0.04822         NaN         NaN
# 4     5                                 LANCET     369,601         NaN                79.321            0.44524         NaN         NaN

# %% [markdown]
# # Rename columns and standardized column values

# %%
df_jcs.rename(columns={'Rank': 'rank_jcr', 'Full Journal Title': 'journal_title', 'Total Cites': 'total_cities_jcr', 'Journal Impact Factor': 'jcr_value'}, inplace = True)
df_scimago.rename(columns={'Rank': 'rank_scimago', 'Title': 'journal_title', 'Total Cites (3years)': 'total_cities_scimago', 'SJR': 'scimago_value', 'Issn': 'issn'}, inplace = True)

cols_to_keep_df1 = ['rank_jcr', 'journal_title', 'total_cities_jcr', 'jcr_value']

cols_to_keep_df2 = ['issn','rank_scimago', 'journal_title', 'total_cities_scimago', 'scimago_value']

df_jcs['journal_title'] = df_jcs['journal_title'].str.title()
df_jcs['total_cities_jcr'] = df_jcs['total_cities_jcr'].str.replace(",","")
df_jcs['jcr_value'] = df_jcs['jcr_value'].str.replace(".",",")

df_jcs_clean = df_jcs[cols_to_keep_df1]
df_scimago_clean = df_scimago[cols_to_keep_df2]

df_scimago_clean.head()
# Out:
#                  issn  rank_scimago                          journal_title  total_cities_scimago scimago_value
# 0  15424863, 00079235             1     Ca-A Cancer Journal for Clinicians                 15499        62,937
# 1  10575987, 15458601             2       MMWR Recommendations and Reports                   492        40,949
# 2  14710072, 14710080             3  Nature Reviews Molecular Cell Biology                 10844        37,461
# 3  00335533, 15314650             4         Quarterly Journal of Economics                  1945        34,573
# 4            20588437             5               Nature Reviews Materials                 11188        32,011

# %%
df_jcs_clean.head()
# Out:
#    rank_jcr                          journal_title total_cities_jcr jcr_value
# 0         1     Ca-A Cancer Journal For Clinicians            55868   508,702
# 1         2  Nature Reviews Molecular Cell Biology            58477    94,444
# 2         3        New England Journal Of Medicine           464351    91,245
# 3         4          Nature Reviews Drug Discovery            41989    84,694
# 4         5                                 Lancet           369601    79,321

# %%
print(df_jcs_clean.count())
print(df_scimago_clean.count())
# Out:
# rank_jcr            13010
# journal_title       13010
# total_cities_jcr    13010
# jcr_value           13010
# dtype: int64
# issn                    32952
# rank_scimago            32952
# journal_title           32952
# total_cities_scimago    32952
# scimago_value           32604
# dtype: int64

# %% [markdown]
# # Merge scimago dataframe with jcs dataframe

# %%
df_jcs_scimago = pd.merge(df_scimago_clean, df_jcs_clean, on="journal_title")
df_jcs_scimago.head()
# Out:
#                  issn  rank_scimago                          journal_title  total_cities_scimago scimago_value  rank_jcr total_cities_jcr jcr_value
# 0  14710072, 14710080             3  Nature Reviews Molecular Cell Biology                 10844        37,461         2            58477    94,444
# 1            20588437             5               Nature Reviews Materials                 11188        32,011         7            19887    66,308
# 2  00928674, 10974172             7                                   Cell                 52644        26,304        33           320407    41,582
# 3  14710056, 14710064             8                Nature Reviews Genetics                  6348        26,214        19            42803    53,242
# 4  14741741, 14741733            11              Nature Reviews Immunology                  8200        20,529        20            55784    53,106

# %% [markdown]
# # Explode issn column of jcs_scimago dataframe

# %%
teste = df_jcs_scimago.copy()
teste.head()
teste['issn'] = teste['issn'].str.split(',', expand=False)
teste = teste.explode('issn').drop_duplicates()
display(teste)
# Out:
#            issn  rank_scimago                          journal_title  total_cities_scimago scimago_value  rank_jcr total_cities_jcr jcr_value
# 0      14710072             3  Nature Reviews Molecular Cell Biology                 10844        37,461         2            58477    94,444
# 0      14710080             3  Nature Reviews Molecular Cell Biology                 10844        37,461         2            58477    94,444
# 1      20588437             5               Nature Reviews Materials                 11188        32,011         7            19887    66,308
# 2      00928674             7                                   Cell                 52644        26,304        33           320407    41,582
# 2      10974172             7                                   Cell                 52644        26,304        33           320407    41,582
# ...         ...           ...                                    ...                   ...           ...       ...              ...       ...
# 4144   09518967         31524        Mediterranean Historical Review                     2         0,101     12898              133     0,158
# 4145   17458706         31574                       Northern History                     1         0,101     12849               80     0,211
# 4145   0078172X         31574                       Northern History                     1         0,101     12849               80     0,211
# 4146   01497952         32166                  German Studies Review                    10         0,100     12902              150     0,156
# 4147   00295507         32347      Nuclear Engineering International                     1         0,100     12955               89     0,081
#
# [6617 rows x 8 columns]

# %% [markdown]
# # Features renaming / selection

# %%
df_all = df_all_raw.copy()
df_all.rename(columns={'ENTRYTYPE': 'type_publication'}, inplace = True)

cols_to_keep = ['author', 'title', 'keywords', 'abstract', 'year', 'type_publication', 'doi', 'issn']

df_all = df_all[cols_to_keep]

df_all.head()
# Out:
#                                               author                                              title                                           keywords                                           abstract  year type_publication                      doi issn
# 0  Jing, Furong and Cao, Yongsheng and Fang, Wei ...  Construction and Implementation of Big Data Fr...  Crop germplasm resources, Data analysis, Big d...  Based on understanding the application of big ...  2019    inproceedings  10.1145/3331453.3361308  NaN
# 1  Gote, Christoph and Mavrodiev, Pavlin and Schw...  Big Data = Big Insights? Operationalising Broo...                                                NaN  Massive data from software repositories and co...  2022    inproceedings  10.1145/3510003.3510619  NaN
# 2  Peng, Michael Yao-Ping and Tuan, Sheng-Hwa and...  Establishment of Business Intelligence and Big...  Database, Business Intelligence, Institutional...  The applications on business intelligence and ...  2017    inproceedings  10.1145/3134271.3134296  NaN
# 3                        Li, Jiale and Liao, Shunbao  Quality Control Framework of Big Data for Earl...  big data, agro-meteorological disasters, early...  Agricultural meteorological disasters, includi...  2019    inproceedings  10.1145/3349341.3349371  NaN
# 4                                 Cuzzocrea, Alfredo  Big Data Management and Analytics in Intellige...  Intelligent smart environments, Big data analy...  This paper focuses on big data management and ...  2019    inproceedings  10.1145/3366030.3366044  NaN

# %% [markdown]
# # Drop

# %%
df_all["issn"] = df_all["issn"].str.replace("-","")

# %% [markdown]
# # Merge .bibtex dataframe with jcr_scimago dataframe

# %%
merged_df = pd.merge(teste,df_all, on="issn")
display(merged_df)
# Out:
#          issn  rank_scimago           journal_title  total_cities_scimago scimago_value  rank_jcr total_cities_jcr jcr_value                                             author                                              title                                           keywords  \
# 0    00928674             7                    Cell                 52644        26,304        33           320407    41,582  Yann Joly and Stephanie O.M. Dyke and Bartha M...  Are Data Sharing and Privacy Protection Mutual...                                                NaN
# 1    00928674             7                    Cell                 52644        26,304        33           320407    41,582  Emma Laks and Andrew McPherson and Hans Zahn a...  Clonal Decomposition and DNA Replication State...  single cell, copy number, aneuploidy, tumor ev...
# 2    00928674             7                    Cell                 52644        26,304        33           320407    41,582  Daisong Wang and Jingqiang Wang and Lanyue Bai...  Long-Term Expansion of Pancreatic Islet Organo...  pancreatic islets, adult stem cells, organoid,...
# 3    00928674             7                    Cell                 52644        26,304        33           320407    41,582  Jiamin Wu and Zhi Lu and Dong Jiang and Yuduo ...  Iterative tomography with digital adaptive opt...  long-term high-speed imaging, adaptive optics,...
# 4    00928674             7                    Cell                 52644        26,304        33           320407    41,582  Tianyi Wang and Wei Wang and Guangmao Xie and ...  Human population history at the crossroads of ...  ancient DNA, 12,000-year-old humans, deeply di...
# ..        ...           ...                     ...                   ...           ...       ...              ...       ...                                                ...                                                ...                                                ...
# 851  00405957         12449                Therapie                   338         0,387      7565             1069     2,070  Jean-Christophe Corvol and Sylvia Goni and Rég...  Translational research on cognitive and behavi...  Neurology, Psychiatrics, Cognition, Behaviour,...
# 852  18744907         13273  Physical Communication                   969         0,354      8418             1412     1,810  Farshad Miramirkhani and Mehdi Karbalayghareh ...  Enabling 5G indoor services for residential en...  Visible light communication (VLC), Ray-tracing...
# 853  18744907         13273  Physical Communication                   969         0,354      8418             1412     1,810      Nida Fatima and Paresh Saxena and Manik Gupta  Integration of multi access edge computing wit...  Unmanned aerial vehicle, Multi-access edge com...
# 854  03623319         13408  Social Science Journal                   340         0,349      6572             1817     2,376                                       Turgut Ozkan  Criminology in the age of data explosion: New ...  Social science, Big data, Crime, Social media,...
# 855  00987913         16171          Serials Review                    57         0,263     12701              232     0,324                                    Katy DiVittorio  2013 North American Serials Interest Group (NA...                                                NaN
#
#                                               abstract  year type_publication                                           doi
# 0    We review emerging strategies to protect the p...  2016          article    https://doi.org/10.1016/j.cell.2016.11.004
# 1    Summary\nAccurate measurement of clonal genoty...  2019          article    https://doi.org/10.1016/j.cell.2019.10.026
# 2    Summary\nIt has generally proven challenging t...  2020          article    https://doi.org/10.1016/j.cell.2020.02.048
# 3    Summary\nLong-term subcellular intravital imag...  2021          article    https://doi.org/10.1016/j.cell.2021.04.029
# 4    Summary\nPast human genetic diversity and migr...  2021          article    https://doi.org/10.1016/j.cell.2021.05.018
# ..                                                 ...   ...              ...                                           ...
# 851  Summary\nThe important medical and social burd...  2016          article  https://doi.org/10.1016/j.therap.2016.01.001
# 852  Visible light communication (VLC) has emerged ...  2022          article  https://doi.org/10.1016/j.phycom.2022.101679
# 853  During the last decade, research and developme...  2022          article  https://doi.org/10.1016/j.phycom.2022.101641
# 854  This review discusses practical benefits and l...  2019          article  https://doi.org/10.1016/j.soscij.2018.10.010
# 855                                                NaN  2013          article  https://doi.org/10.1016/j.serrev.2013.10.016
#
# [856 rows x 15 columns]

# %% [markdown]
# # Dtypes

# %%
merged_df.dtypes
# Out:
# issn                    object
# rank_scimago             int64
# journal_title           object
# total_cities_scimago     int64
# scimago_value           object
# rank_jcr                 int64
# total_cities_jcr        object
# jcr_value               object
# author                  object
# title                   object
# keywords                object
# abstract                object
# year                    object
# type_publication        object
# doi                     object
# dtype: object

# %%
#Adjusting "year" feature dtype
merged_df['year'] = merged_df.year.astype('int64')
print('dtypes:\n', df_all.dtypes, '\n')

#Sorting values by "year"
merged_df = merged_df.sort_values('year')
display(merged_df.head())
# Out:
# dtypes:
#  author              object
# title               object
# keywords            object
# abstract            object
# year                object
# type_publication    object
# doi                 object
# issn                object
# dtype: object
#          issn  rank_scimago                     journal_title  total_cities_scimago scimago_value  rank_jcr total_cities_jcr jcr_value                                             author                                              title                                           keywords  \
# 32   00128252           408             Earth-Science Reviews                  7358         3,893       311            27304    12,413                                          A. Hubaux                     A new geological tool-the data                                                NaN
# 741  01403664          8052           Computer Communications                  2424         0,627      4546             6725     3,167       C.K Yeo and S.C Hui and I.Y Soon and B.S Lee  An adaptive protocol for real-time fax communi...  Internet faxing, Adaptive fax communication, R...
# 139  00063207          1105           Biological Conservation                  7021         2,227      1353            39669     5,990  Brian L. Sullivan and Christopher L. Wood and ...  eBird: A citizen-based bird observation networ...  eBird, Citizen-science, Observation network, S...
# 513  1470160X          2829             Ecological Indicators                 12850         1,315      2031            32205     4,958  C. Zucca and R. Della Peruta and R. Salvia and...  Towards a World Desertification Atlas. Relatin...  UNCCD, Land degradation, Indicator frameworks,...
# 171  0740624X          1194  Government Information Quarterly                  1946         2,121       876             5379     7,279                    Gwanhoo Lee and Young Hoon Kwak  An Open Government Maturity Model for social m...  Open government, Social media, Public engageme...
#
#                                               abstract  year type_publication                                            doi
# 32   Today data processing technology offers new an...  1973          article   https://doi.org/10.1016/0012-8252(73)90089-5
# 741  Internet faxing allows users from different lo...  2001          article  https://doi.org/10.1016/S0140-3664(00)00342-X
# 139  New technologies are rapidly changing the way ...  2009          article   https://doi.org/10.1016/j.biocon.2009.05.006
# 513  Mapping land degradation and desertification (...  2012          article  https://doi.org/10.1016/j.ecolind.2011.09.012
# 171  Social media has opened up unprecedented new p...  2012          article      https://doi.org/10.1016/j.giq.2012.06.001

# %% [markdown]
# # NaN analysis

# %%
print('Shape: ',merged_df.shape,'\n')
print(f'Nan Analysis: \n{merged_df.isna().sum()}\n')
# Out:
# Shape:  (856, 15)
#
# Nan Analysis:
# issn                     0
# rank_scimago             0
# journal_title            0
# total_cities_scimago     0
# scimago_value            0
# rank_jcr                 0
# total_cities_jcr         0
# jcr_value                0
# author                  30
# title                    2
# keywords                84
# abstract                62
# year                     0
# type_publication         0
# doi                      0
# dtype: int64

# %%
print('Shape before dropna: ', merged_df.shape)
merged_df.dropna(axis = 0, inplace = True)
print('Shape after dropna: ', merged_df.shape)
# Out:
# Shape before dropna:  (856, 15)
# Shape after dropna:  (769, 15)

# %% [markdown]
# # Drop duplicates

# %%
print('Shape before drop_duplicates: ',merged_df.shape)
merged_df.drop_duplicates(inplace = True)
print('Shape after drop_duplicates: ',merged_df.shape)
# Out:
# Shape before drop_duplicates:  (769, 15)
# Shape after drop_duplicates:  (766, 15)

# %%
display(merged_df)
# Out:
#          issn  rank_scimago                     journal_title  total_cities_scimago scimago_value  rank_jcr total_cities_jcr jcr_value                                             author                                              title                                           keywords  \
# 741  01403664          8052           Computer Communications                  2424         0,627      4546             6725     3,167       C.K Yeo and S.C Hui and I.Y Soon and B.S Lee  An adaptive protocol for real-time fax communi...  Internet faxing, Adaptive fax communication, R...
# 139  00063207          1105           Biological Conservation                  7021         2,227      1353            39669     5,990  Brian L. Sullivan and Christopher L. Wood and ...  eBird: A citizen-based bird observation networ...  eBird, Citizen-science, Observation network, S...
# 513  1470160X          2829             Ecological Indicators                 12850         1,315      2031            32205     4,958  C. Zucca and R. Della Peruta and R. Salvia and...  Towards a World Desertification Atlas. Relatin...  UNCCD, Land degradation, Indicator frameworks,...
# 171  0740624X          1194  Government Information Quarterly                  1946         2,121       876             5379     7,279                    Gwanhoo Lee and Young Hoon Kwak  An Open Government Maturity Model for social m...  Open government, Social media, Public engageme...
# 350  01679236          2113          Decision Support Systems                  2672         1,564      1455            13580     5,795                    Haluk Demirkan and Dursun Delen  Leveraging the capabilities of service-oriente...  Cloud computing, Service orientation, Service ...
# ..        ...           ...                               ...                   ...           ...       ...              ...       ...                                                ...                                                ...                                                ...
# 431  00200255          2220              Information Sciences                 17554         1,524      1030            44038     6,795  Michal Moran and Tom Cohen and Yuval Ben-Zion ...                         Curious instance selection  Intrinsic motivation learning, Curiosity loop,...
# 122  10534822           880  Human Resource Management Review                  1006         2,549       830             3952     7,444  Soumyadeb Chowdhury and Prasanta Dey and Sian ...  Unlocking the value of artificial intelligence...  Artificial intelligence, Organisational resour...
# 439  00313203          2302               Pattern Recognition                 12476         1,492       767            33363     7,740  Chengyang Li and Liping Zhu and Gangyi Tian an...  Rethinking referring relationships from a pers...  Referring relationship, Multimodal learning, I...
# 659  01651684          5098                 Signal Processing                  5800         0,907      2276            15960     4,662  Mingchi Ju and Man Zhao and Tailin Han and Hon...  A novel subspace pursuit of residual correlati...  Distributed compressed sensing, Sparse reconst...
# 477  09567135          2649                      Food Control                  9417         1,371      1587            30556     5,548  Lorenzo Serva and Giorgio Marchesini and Marco...  Testing two NIRs instruments to predict chicke...  Chicken, Genotype, Myopathies, Meat quality, N...
#
#                                               abstract  year type_publication                                             doi
# 741  Internet faxing allows users from different lo...  2001          article   https://doi.org/10.1016/S0140-3664(00)00342-X
# 139  New technologies are rapidly changing the way ...  2009          article    https://doi.org/10.1016/j.biocon.2009.05.006
# 513  Mapping land degradation and desertification (...  2012          article   https://doi.org/10.1016/j.ecolind.2011.09.012
# 171  Social media has opened up unprecedented new p...  2012          article       https://doi.org/10.1016/j.giq.2012.06.001
# 350  Using service-oriented decision support system...  2013          article       https://doi.org/10.1016/j.dss.2012.05.048
# ..                                                 ...   ...              ...                                             ...
# 431  In the process of building machine learning mo...  2022          article       https://doi.org/10.1016/j.ins.2022.07.025
# 122  Artificial Intelligence (AI) is increasingly a...  2022          article      https://doi.org/10.1016/j.hrmr.2022.100899
# 439  Referring relationship aims at localizing subj...  2023          article    https://doi.org/10.1016/j.patcog.2022.109044
# 659  Multi-signal joint reconstruction is critical ...  2023          article    https://doi.org/10.1016/j.sigpro.2022.108747
# 477  To discriminate among three poultry meat types...  2023          article  https://doi.org/10.1016/j.foodcont.2022.109391
#
# [766 rows x 15 columns]

# %% [markdown]
# # Export

# %% [markdown]
# ## Creating 03_OutputFiles if not exists

# %%
if not os.path.exists('../03_OutputFiles/'):
  os.makedirs('../03_OutputFiles/')

# %% [markdown]
# ## Creating yaml file if not exists

# %%
if not os.path.exists("configuration.yaml"):
  configuration_dict = {
        'output_extensions': ['csv', 'json', 'yaml'],
        'filter_atributes': ['title', 'keywords', 'abstract', 'year', 'type_publication', 'doi', 'jcr_value', 'scimago_value']
    }
  with open('configuration.yaml', 'w') as yamlfile:
    data = yaml.dump(configuration_dict, yamlfile)

configuration_file = read_yaml("configuration.yaml")
# Out:
# configuration.yaml read successfully

# %% [markdown]
# # Filter Columns

# %%
filter_columns = configuration_file['filter_atributes']
print("Filters selected: ", configuration_file['filter_atributes'])

if filter_columns:
    final_df = merged_df.filter(items=filter_columns)
else:
    print("Using all dataframe columns")
    final_df = merged_df
final_df.head()
# Out:
# Filters selected:  ['title']
#                                                  title
# 741  An adaptive protocol for real-time fax communi...
# 139  eBird: A citizen-based bird observation networ...
# 513  Towards a World Desertification Atlas. Relatin...
# 171  An Open Government Maturity Model for social m...
# 350  Leveraging the capabilities of service-oriente...

# %% [markdown]
# ## Reading yaml file and exporting

# %%
print("Output extensions options: ", configuration_file['output_extensions'])

if 'csv' in configuration_file['output_extensions']:
    write_csv(df_all, 'df_all')
if 'json' in configuration_file['output_extensions']:
    write_json(df_all, 'df_all')
if 'yaml' in configuration_file['output_extensions']:
    write_yaml(df_all, 'df_all')
if not configuration_file['output_extensions']:
  raise Exception("Please, select an output file extension")
# Out:
# Output extensions options:  ['csv', 'json', 'yaml']
# df_all.csv successfully written
# df_all.json successfully written
# df_all.yaml successfully written
